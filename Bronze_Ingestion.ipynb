# %%
orders_df = (
    spark.read
    .option("header", "true")
    .csv("/Volumes/retailx_catalog/default/landing_zone/orders.csv")
)

orders_df.write.mode("overwrite") \
.saveAsTable("retailx_catalog.bronze.orders")

# %%
customers_df = (
    spark.read
    .option("header", "true")
    .csv("/Volumes/retailx_catalog/default/landing_zone/customers.csv")
)

customers_df.write.mode("overwrite") \
.saveAsTable("retailx_catalog.bronze.customers")
