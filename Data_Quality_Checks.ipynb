# %%
# %sql
-- Invalid amounts filtered in Silver
SELECT * FROM retailx_catalog.bronze.orders
WHERE AMOUNT IS NULL OR AMOUNT <= 0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ORDER_ID</th><th>CUSTOMER_ID</th><th>ORDER_DATE</th><th>AMOUNT</th></tr></thead><tbody><tr><td>3</td><td>103</td><td>03-02-2024</td><td>null</td></tr><tr><td>6</td><td>106</td><td>06-02-2024</td><td>-100</td></tr><tr><td>7</td><td>107</td><td>08-02-2024</td><td>null</td></tr><tr><td>10</td><td>110</td><td>07-02-2024</td><td>-200</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM retailx_catalog.bronze.orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT * FROM retailx_catalog.silver.orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ORDER_ID</th><th>CUSTOMER_ID</th><th>ORDER_DATE</th><th>AMOUNT</th></tr></thead><tbody><tr><td>1</td><td>101</td><td>2024-02-01</td><td>250.0</td></tr><tr><td>2</td><td>102</td><td>2024-02-02</td><td>300.0</td></tr><tr><td>4</td><td>104</td><td>2024-02-04</td><td>350.0</td></tr><tr><td>5</td><td>105</td><td>2024-02-05</td><td>400.0</td></tr><tr><td>8</td><td>108</td><td>2024-02-04</td><td>450.0</td></tr><tr><td>9</td><td>109</td><td>2024-02-05</td><td>500.0</td></tr></tbody></table></div>

# %%
# %sql
-- Invalid emails filtered in Silver
SELECT * FROM retailx_catalog.bronze.customers
WHERE EMAIL IS NULL OR EMAIL NOT LIKE '%@%';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CUSTOMER_ID</th><th>NAME</th><th>EMAIL</th><th>CREATED_DATE</th></tr></thead><tbody><tr><td>102</td><td>Arjun</td><td>arjun.gmail.com</td><td>25-01-2024</td></tr><tr><td>104</td><td>Akash</td><td>null</td><td>27-01-2024</td></tr><tr><td>108</td><td>Banu</td><td>null</td><td>27-01-2024</td></tr><tr><td>110</td><td>Balaji</td><td>balaji.gmail.com</td><td>24-01-2024</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM retailx_catalog.bronze.orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT * FROM retailx_catalog.silver.customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CUSTOMER_ID</th><th>NAME</th><th>EMAIL</th><th>CREATED_DATE</th></tr></thead><tbody><tr><td>101</td><td>Ashwin</td><td>ashwin@gmail.com</td><td>2024-01-24</td></tr><tr><td>103</td><td>Arun</td><td>arun@gmail.com</td><td>2024-01-26</td></tr><tr><td>105</td><td>Abi</td><td>abi@gmail.com</td><td>2024-01-28</td></tr><tr><td>106</td><td>Ajay</td><td>ajay@gmail.com</td><td>2024-01-29</td></tr><tr><td>107</td><td>Bala</td><td>bala@gmail.com</td><td>2024-01-30</td></tr><tr><td>109</td><td>Barath</td><td>barath@gmail.com</td><td>2024-01-28</td></tr></tbody></table></div>
