# %%
#Oracle logic:
    
SELECT SUM(amount) FROM orders;

# %%
# %sql
SELECT SUM(AMOUNT) AS TOTAL_AMOUNT
FROM retailx_catalog.silver.orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TOTAL_AMOUNT</th></tr></thead><tbody><tr><td>2250.0</td></tr></tbody></table></div>
